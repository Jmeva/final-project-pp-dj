# %% [markdown]
# # Carga de datos — ISSSTE, IMSS e IMSS Bienestar
#
# Este notebook carga los tres datasets de surtimiento de recetas y los prepara para el modelo Beta-Binomial jerárquico.
#
# | Institución | Fuente | Granularidad | Estados | Años |
# |---|---|---|---|---|
# | ISSSTE | CSV (`agg_folio_2018_2024.csv`) | Anual (agregado desde mensual) | 32 | 2018–2024 |
# | IMSS | Excel (hoja `Recetas`) | Anual | 32 | 2019–2024* |
# | IMSS Bienestar | Excel (4 hojas wide) | Anual | 20 | 2017–2024* |
#
# \* Datos de 2024 parciales (hasta abril).

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Añadir src/ al path para importar módulos locales
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT / 'src'))

from load_data import load_all, load_issste, load_imss, load_imss_bienestar
from bayes_data import build_model_inputs

DATA_DIR = ROOT / 'data'
plt.rcParams.update({'figure.dpi': 120, 'font.size': 10})

# %% [markdown]
# ## 1. Carga individual por institución

# %%
issste = load_issste(DATA_DIR / 'agg_folio_2018_2024.csv')
imss   = load_imss(DATA_DIR / 'IMSS_2019_ABRIL2024_ANUAL_SOLICITUD 330018024016694 ANEXO I.xlsx')
bw     = load_imss_bienestar(DATA_DIR / 'IMSS_BIENESTAR_2017_ABRIL2024_ANUAL_SOLICITUD 330018024016695 ANEXO I.xlsx')

for nombre, df in [('ISSSTE', issste), ('IMSS', imss), ('IMSS Bienestar', bw)]:
    print(f"{'='*50}")
    print(f"  {nombre}  |  {df.shape[0]} filas  |  {df.estado.nunique()} estados  |  años: {sorted(df.anio.unique())}")
    print(df.to_string(index=False))
# Out:
# ==================================================
#   ISSSTE  |  224 filas  |  32 estados  |  años: [np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]
#              estado  anio  surtidas   total institucion
#      AGUASCALIENTES  2018    499160  503813      ISSSTE
#      AGUASCALIENTES  2019    470536  477426      ISSSTE
#      AGUASCALIENTES  2020    351012  372130      ISSSTE
#      AGUASCALIENTES  2021    350040  359803      ISSSTE
#      AGUASCALIENTES  2022    457139  466302      ISSSTE
#      AGUASCALIENTES  2023    506976  515213      ISSSTE
#      AGUASCALIENTES  2024    489385  504324      ISSSTE
#     BAJA CALIFORNIA  2018    667804  681223      ISSSTE
#     BAJA CALIFORNIA  2019    609113  629036      ISSSTE
#     BAJA CALIFORNIA  2020    495058  537997      ISSSTE
#     BAJA CALIFORNIA  2021    492065  522899      ISSSTE
#     BAJA CALIFORNIA  2022    583478  613154      ISSSTE
#     BAJA CALIFORNIA  2023    661711  688186      ISSSTE
#     BAJA CALIFORNIA  2024    749718  772995      ISSSTE
# BAJA CALIFORNIA SUR  2018    578887  590685      ISSSTE
# BAJA CALIFORNIA SUR  2019    536151  548892      ISSSTE
# BAJA CALIFORNIA SUR  2020    432500  449440      ISSSTE
# BAJA CALIFORNIA SUR  2021    409321  422139      ISSSTE
# BAJA CALIFORNIA SUR  2022    530913  551462      ISSSTE
# BAJA CALIFORNIA SUR  2023    606546  623867      ISSSTE
# BAJA CALIFORNIA SUR  2024    671229  680148      ISSSTE
#            CAMPECHE  2018    424675  427763      ISSSTE
#            CAMPECHE  2019    389949  397100      ISSSTE
#            CAMPECHE  2020    312511  324401      ISSSTE
#            CAMPECHE  2021    305335  318841      ISSSTE
#            CAMPECHE  2022    356029  385558      ISSSTE
#            CAMPECHE  2023    400470  423205      ISSSTE
#            CAMPECHE  2024    448933  459408      ISSSTE
#                CDMX  2018   7421888 7460648      ISSSTE
#                CDMX  2019   7106028 7152587      ISSSTE
#                CDMX  2020   5138653 5203461      ISSSTE
#                CDMX  2021   5073363 5153263      ISSSTE
#                CDMX  2022   6671050 6779615      ISSSTE
#                CDMX  2023   7604544 7718753      ISSSTE
#                CDMX  2024   7557326 7698083      ISSSTE
#             CHIAPAS  2018    971620  997905      ISSSTE
#             CHIAPAS  2019    917111  943125      ISSSTE
#             CHIAPAS  2020    661047  678862      ISSSTE
#             CHIAPAS  2021    673460  687312      ISSSTE
#             CHIAPAS  2022    863286  878387      ISSSTE
#             CHIAPAS  2023   1007862 1028076      ISSSTE
#             CHIAPAS  2024   1146173 1168674      ISSSTE
#           CHIHUAHUA  2018   1355191 1388287      ISSSTE
#           CHIHUAHUA  2019   1287965 1319447      ISSSTE
#           CHIHUAHUA  2020   1096325 1157200      ISSSTE
#           CHIHUAHUA  2021   1119473 1147279      ISSSTE
#           CHIHUAHUA  2022   1324090 1350571      ISSSTE
#           CHIHUAHUA  2023   1502313 1531110      ISSSTE
#           CHIHUAHUA  2024   1630557 1665335      ISSSTE
#            COAHUILA  2018    979898 1007988      ISSSTE
#            COAHUILA  2019    915279  940117      ISSSTE
#            COAHUILA  2020    691962  724582      ISSSTE
#            COAHUILA  2021    701338  721939      ISSSTE
#            COAHUILA  2022    878708  899230      ISSSTE
#            COAHUILA  2023    991528 1011410      ISSSTE
#            COAHUILA  2024   1150960 1168090      ISSSTE
#              COLIMA  2018    241166  244273      ISSSTE
#              COLIMA  2019    231288  236355      ISSSTE
#              COLIMA  2020    207626  213557      ISSSTE
#              COLIMA  2021    201665  206466      ISSSTE
#              COLIMA  2022    253156  258019      ISSSTE
#              COLIMA  2023    287519  297201      ISSSTE
#              COLIMA  2024    330900  337163      ISSSTE
#             DURANGO  2018   1147984 1164726      ISSSTE
#             DURANGO  2019   1111727 1124614      ISSSTE
#             DURANGO  2020    867424  880619      ISSSTE
#             DURANGO  2021    852995  860885      ISSSTE
#             DURANGO  2022   1070030 1079300      ISSSTE
#             DURANGO  2023   1237796 1253602      ISSSTE
#             DURANGO  2024   1366128 1375265      ISSSTE
#          GUANAJUATO  2018   1196765 1240621      ISSSTE
#          GUANAJUATO  2019   1156649 1198366      ISSSTE
#          GUANAJUATO  2020    895305  947056      ISSSTE
#          GUANAJUATO  2021    847466  878912      ISSSTE
#          GUANAJUATO  2022   1158631 1192934      ISSSTE
#          NUEVO LEÓN  2024    811377  852953      ISSSTE
#              OAXACA  2018    720800  773054      ISSSTE
#              OAXACA  2019    710114  774280      ISSSTE
#              OAXACA  2020    460872  532055      ISSSTE
#              OAXACA  2021    441417  513155      ISSSTE
#              OAXACA  2022    634412  703291      ISSSTE
#              OAXACA  2023    763676  801743      ISSSTE
#              OAXACA  2024    867439  886641      ISSSTE
#              PUEBLA  2018    919364  940332      ISSSTE
#              PUEBLA  2019    880294  902857      ISSSTE
#              PUEBLA  2020    694725  716892      ISSSTE
#              PUEBLA  2021    676448  686446      ISSSTE
#              PUEBLA  2022    898465  918073      ISSSTE
#              PUEBLA  2023   1041138 1061222      ISSSTE
#              PUEBLA  2024   1143023 1154682      ISSSTE
#           QUERETARO  2018    478333  483702      ISSSTE
#           QUERETARO  2019    437829  445055      ISSSTE
#           QUERETARO  2020    338560  355797      ISSSTE
#           QUERETARO  2021    345819  349200      ISSSTE
#           QUERETARO  2022    449813  453188      ISSSTE
#           QUERETARO  2023    492659  495236      ISSSTE
#           QUERETARO  2024    537343  542579      ISSSTE
#        QUINTANA ROO  2018    398392  403394      ISSSTE
#        QUINTANA ROO  2019    381354  386387      ISSSTE
#        QUINTANA ROO  2020    271825  283390      ISSSTE
#        QUINTANA ROO  2021    271378  280208      ISSSTE
#        QUINTANA ROO  2022    339684  349605      ISSSTE
#        QUINTANA ROO  2023    389695  398904      ISSSTE
#        QUINTANA ROO  2024    434382  439037      ISSSTE
#     SAN LUIS POTOSI  2018   1033407 1055169      ISSSTE
#     SAN LUIS POTOSI  2019    961713  988440      ISSSTE
#     SAN LUIS POTOSI  2020    722704  753689      ISSSTE
#     SAN LUIS POTOSI  2021    685962  713578      ISSSTE
#     SAN LUIS POTOSI  2022    882196  905108      ISSSTE
#     SAN LUIS POTOSI  2023   1049291 1059525      ISSSTE
#     SAN LUIS POTOSI  2024   1142696 1148804      ISSSTE
#             SINALOA  2018   1787583 1849236      ISSSTE
#             SINALOA  2019   1706581 1766013      ISSSTE
#             SINALOA  2020   1191831 1248711      ISSSTE
#             SINALOA  2021   1127163 1166732      ISSSTE
#             SINALOA  2022   1479613 1521753      ISSSTE
#             SINALOA  2023   1757266 1807497      ISSSTE
#             SINALOA  2024   1939755 1980255      ISSSTE
#              SONORA  2018    999148 1028641      ISSSTE
#              SONORA  2019    950071  976218      ISSSTE
#              SONORA  2020    788217  821252      ISSSTE
#              SONORA  2021    790646  809446      ISSSTE
#              SONORA  2022    917394  943278      ISSSTE
#              SONORA  2023   1007471 1039630      ISSSTE
#              SONORA  2024   1040911 1064696      ISSSTE
#             TABASCO  2018    525303  541524      ISSSTE
#             TABASCO  2019    476155  489245      ISSSTE
#             TABASCO  2020    342922  352032      ISSSTE
#             TABASCO  2021    345782  353438      ISSSTE
#             TABASCO  2022    467612  479231      ISSSTE
#             TABASCO  2023    586558  603053      ISSSTE
#             TABASCO  2024    565574  585332      ISSSTE
#          TAMAULIPAS  2018   1163777 1187261      ISSSTE
#          TAMAULIPAS  2019   1042543 1063137      ISSSTE
#          TAMAULIPAS  2020    728506  754878      ISSSTE
#          TAMAULIPAS  2021    701951  715549      ISSSTE
#          TAMAULIPAS  2022    866649  892201      ISSSTE
#          TAMAULIPAS  2023   1005961 1033300      ISSSTE
#          TAMAULIPAS  2024   1161347 1184281      ISSSTE
#            TLAXCALA  2018    436803  438640      ISSSTE
#            TLAXCALA  2019    426844  429534      ISSSTE
#            TLAXCALA  2020    361210  363556      ISSSTE
#            TLAXCALA  2021    336267  339727      ISSSTE
#            TLAXCALA  2022    467594  471042      ISSSTE
#            TLAXCALA  2023    523713  527170      ISSSTE
#            TLAXCALA  2024    530430  535350      ISSSTE
#            VERACRUZ  2018   1592414 1614355      ISSSTE
#            VERACRUZ  2019   1510809 1535355      ISSSTE
#            VERACRUZ  2020   1050346 1072872      ISSSTE
#            VERACRUZ  2021   1112638 1137237      ISSSTE
#            VERACRUZ  2022   1400192 1428315      ISSSTE
#            VERACRUZ  2023   1589933 1612748      ISSSTE
#            VERACRUZ  2024   1731217 1756723      ISSSTE
#             YUCATÁN  2018    931044  953238      ISSSTE
#             YUCATÁN  2019    883431  920840      ISSSTE
#             YUCATÁN  2020    660167  698270      ISSSTE
#             YUCATÁN  2021    657212  677755      ISSSTE
#             YUCATÁN  2022    799782  818704      ISSSTE
#             YUCATÁN  2023    920593  933554      ISSSTE
#             YUCATÁN  2024    863407  889633      ISSSTE
#           ZACATECAS  2018    676860  711865      ISSSTE
#           ZACATECAS  2019    650165  669580      ISSSTE
#           ZACATECAS  2020    549149  567036      ISSSTE
#           ZACATECAS  2021    528401  540466      ISSSTE
#           ZACATECAS  2022    698058  721803      ISSSTE
#           ZACATECAS  2023    802731  822587      ISSSTE
#           ZACATECAS  2024    807839  826620      ISSSTE
# ==================================================
#   IMSS  |  192 filas  |  32 estados  |  años: [np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]
#              estado  anio  surtidas    total institucion
#      AGUASCALIENTES  2019   4334260  4338906        IMSS
#     BAJA CALIFORNIA  2019   7801411  7939701        IMSS
# BAJA CALIFORNIA SUR  2019   1782398  1791899        IMSS
#            CAMPECHE  2019   1356076  1396929        IMSS
#             CHIAPAS  2019   3012070  3070453        IMSS
#           CHIHUAHUA  2019   9801809 10270460        IMSS
#                CDMX  2019  27531080 27672230        IMSS
#            COAHUILA  2019   8876910  9205623        IMSS
#              COLIMA  2019   1703677  1756279        IMSS
#             DURANGO  2019   4358134  4535460        IMSS
#              MÉXICO  2019  24120382 24659663        IMSS
#          GUANAJUATO  2019   9326750  9603807        IMSS
#            GUERRERO  2019   3442519  3492367        IMSS
#             HIDALGO  2019   2967282  3051135        IMSS
#             JALISCO  2019  18578271 18877116        IMSS
#           MICHOACÁN  2019   6636222  6902091        IMSS
#             MORELOS  2019   3518152  3614595        IMSS
#             NAYARIT  2019   2501853  2563463        IMSS
#            GUERRERO  2021   3022980  3327103        IMSS
#             HIDALGO  2021   2547845  2931704        IMSS
#             JALISCO  2021  15827424 17863366        IMSS
#           MICHOACÁN  2021   5931360  7032816        IMSS
#             MORELOS  2021   3259558  3683572        IMSS
#             NAYARIT  2021   2398612  2577949        IMSS
#          NUEVO LEÓN  2021  11499211 12925518        IMSS
#              OAXACA  2021   1743410  1987103        IMSS
#              PUEBLA  2021   6160522  6774400        IMSS
#           QUERETARO  2021   3238983  3941505        IMSS
#        QUINTANA ROO  2021   2052119  2273242        IMSS
#     SAN LUIS POTOSI  2021   4326213  5018010        IMSS
#             SINALOA  2021   8031187  8685630        IMSS
#              SONORA  2021   7027118  8024276        IMSS
#             TABASCO  2021   1671797  2023943        IMSS
#          TAMAULIPAS  2021   5229952  5930350        IMSS
#            TLAXCALA  2021   1296997  1474180        IMSS
#            VERACRUZ  2021  10020363 11008858        IMSS
#             YUCATÁN  2021   4246656  4833055        IMSS
#           ZACATECAS  2021   2428077  2786651        IMSS
#      AGUASCALIENTES  2022   4382755  4557129        IMSS
#     BAJA CALIFORNIA  2022   7689567  8167976        IMSS
# BAJA CALIFORNIA SUR  2022   1878125  1913822        IMSS
#            CAMPECHE  2022   1344165  1455131        IMSS
#             CHIAPAS  2022   3076434  3284747        IMSS
#           CHIHUAHUA  2022   9533428 10544830        IMSS
#                CDMX  2022  28247246 28711134        IMSS
#            COAHUILA  2022   8721913  9283563        IMSS
#              COLIMA  2022   1758105  1817875        IMSS
#             DURANGO  2022   4287335  4683515        IMSS
#              MÉXICO  2022  24141520 25336306        IMSS
#          GUANAJUATO  2022  10085172 10501459        IMSS
#            GUERRERO  2022   3480073  3638708        IMSS
#             HIDALGO  2022   3068815  3287539        IMSS
#             JALISCO  2022  18174722 19223803        IMSS
#           MICHOACÁN  2022   6663987  7220188        IMSS
#             MORELOS  2022   3674933  3972413        IMSS
#             NAYARIT  2022   2719182  2817869        IMSS
#          NUEVO LEÓN  2022  13274462 13994264        IMSS
#              OAXACA  2022   2078088  2241907        IMSS
#              PUEBLA  2022   7120095  7584602        IMSS
#           QUERETARO  2022   4165089  4369495        IMSS
#        QUINTANA ROO  2022   2473458  2618600        IMSS
#     SAN LUIS POTOSI  2022   4856427  5248250        IMSS
#             SINALOA  2022   9075606  9547745        IMSS
#              SONORA  2022   7680940  8309062        IMSS
#             TABASCO  2022   2096620  2314634        IMSS
#          TAMAULIPAS  2022   5848879  6128041        IMSS
#            TLAXCALA  2022   1543244  1652644        IMSS
#            VERACRUZ  2022  11572627 12223675        IMSS
#             YUCATÁN  2022   4992201  5274984        IMSS
#           ZACATECAS  2022   2710834  2973522        IMSS
#      AGUASCALIENTES  2023   4971284  5053481        IMSS
#     BAJA CALIFORNIA  2023   8643353  8917299        IMSS
# BAJA CALIFORNIA SUR  2023   2099912  2125595        IMSS
#            CAMPECHE  2023   1537598  1556717        IMSS
#             CHIAPAS  2023   3561730  3683299        IMSS
# ==================================================
#   IMSS Bienestar  |  160 filas  |  20 estados  |  años: [np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]
#          estado  anio  surtidas  total    institucion
# BAJA CALIFORNIA  2017     42716  43459 IMSS Bienestar
#        CAMPECHE  2017     60824  65762 IMSS Bienestar
#         CHIAPAS  2017    242218 257611 IMSS Bienestar
#       CHIHUAHUA  2017    155062 159414 IMSS Bienestar
#        COAHUILA  2017    126243 129131 IMSS Bienestar
#         DURANGO  2017    214025 216969 IMSS Bienestar
#        GUERRERO  2017     19938  22458 IMSS Bienestar
#         HIDALGO  2017    212804 215072 IMSS Bienestar
#          MÉXICO  2017     62446  63283 IMSS Bienestar
#       MICHOACÁN  2017    354149 372525 IMSS Bienestar
#         NAYARIT  2017     43230  44240 IMSS Bienestar
#          OAXACA  2017    354784 360902 IMSS Bienestar
#          PUEBLA  2017    294079 306711 IMSS Bienestar
# SAN LUIS POTOSI  2017    283458 292366 IMSS Bienestar
#         SINALOA  2017    152919 153853 IMSS Bienestar
#          SONORA  2017         0      0 IMSS Bienestar
#      TAMAULIPAS  2017    154781 166142 IMSS Bienestar
#        VERACRUZ  2017    184259 192498 IMSS Bienestar
#         YUCATÁN  2017    118742 122500 IMSS Bienestar
#       ZACATECAS  2017    187116 188677 IMSS Bienestar
# BAJA CALIFORNIA  2018     43891  45607 IMSS Bienestar
#        CAMPECHE  2018     61451  67243 IMSS Bienestar
#         CHIAPAS  2018    240642 246072 IMSS Bienestar
#       CHIHUAHUA  2018    152415 156678 IMSS Bienestar
#        COAHUILA  2018    120896 122643 IMSS Bienestar
#         DURANGO  2018    209625 216411 IMSS Bienestar
#        GUERRERO  2018     20782  22610 IMSS Bienestar
#         HIDALGO  2018    210745 213179 IMSS Bienestar
#          MÉXICO  2018     67757  68177 IMSS Bienestar
#       MICHOACÁN  2018    339957 367342 IMSS Bienestar
#         NAYARIT  2018      9188   9746 IMSS Bienestar
#          OAXACA  2018    352577 359084 IMSS Bienestar
#          PUEBLA  2018    280797 297739 IMSS Bienestar
# SAN LUIS POTOSI  2018    303771 313037 IMSS Bienestar
#         SINALOA  2018    141875 142633 IMSS Bienestar
#          SONORA  2018         0      0 IMSS Bienestar
#      TAMAULIPAS  2018    140107 153713 IMSS Bienestar
#        VERACRUZ  2018    172390 181490 IMSS Bienestar
#         YUCATÁN  2018    116089 120553 IMSS Bienestar
#       ZACATECAS  2018    182543 184404 IMSS Bienestar
# BAJA CALIFORNIA  2019     43298  45309 IMSS Bienestar
#        CAMPECHE  2019     56859  61258 IMSS Bienestar
#         CHIAPAS  2019    259485 265282 IMSS Bienestar
#       CHIHUAHUA  2019    155198 162899 IMSS Bienestar
#        COAHUILA  2019    116752 120043 IMSS Bienestar
#         DURANGO  2019    201557 211540 IMSS Bienestar
#        GUERRERO  2019     23830  27237 IMSS Bienestar
#         HIDALGO  2019    200010 203806 IMSS Bienestar
# BAJA CALIFORNIA  2022     37782  42514 IMSS Bienestar
#        CAMPECHE  2022     34498  39526 IMSS Bienestar
#         CHIAPAS  2022    174514 192544 IMSS Bienestar
#       CHIHUAHUA  2022    100693 119272 IMSS Bienestar
#        COAHUILA  2022     83770  86629 IMSS Bienestar
#         DURANGO  2022    150162 163883 IMSS Bienestar
#        GUERRERO  2022     20235  23149 IMSS Bienestar
#         HIDALGO  2022    146172 157509 IMSS Bienestar
#          MÉXICO  2022     55308  59858 IMSS Bienestar
#       MICHOACÁN  2022    190525 220002 IMSS Bienestar
#         NAYARIT  2022     33361  34901 IMSS Bienestar
#          OAXACA  2022    284994 310586 IMSS Bienestar
#          PUEBLA  2022    152063 174752 IMSS Bienestar
# SAN LUIS POTOSI  2022    180282 221194 IMSS Bienestar
#         SINALOA  2022    112397 117376 IMSS Bienestar
#          SONORA  2022         0      0 IMSS Bienestar
#      TAMAULIPAS  2022     76045  83114 IMSS Bienestar
#        VERACRUZ  2022    123417 135672 IMSS Bienestar
#         YUCATÁN  2022     77079  82041 IMSS Bienestar
#       ZACATECAS  2022    140761 146583 IMSS Bienestar
# BAJA CALIFORNIA  2023     16615  16622 IMSS Bienestar
#        CAMPECHE  2023     59383  64252 IMSS Bienestar
#         CHIAPAS  2023    206027 221162 IMSS Bienestar
#       CHIHUAHUA  2023     81851  92656 IMSS Bienestar
#        COAHUILA  2023     86779  92359 IMSS Bienestar
#         DURANGO  2023    176385 187673 IMSS Bienestar
#        GUERRERO  2023     41565  43595 IMSS Bienestar
#         HIDALGO  2023    160472 166432 IMSS Bienestar
#          MÉXICO  2023     65316  66834 IMSS Bienestar
#       MICHOACÁN  2023    235749 253002 IMSS Bienestar
#         NAYARIT  2023     27344  29665 IMSS Bienestar
#          OAXACA  2023    309849 315410 IMSS Bienestar
#          PUEBLA  2023    192339 205108 IMSS Bienestar
# SAN LUIS POTOSI  2023    200980 226574 IMSS Bienestar
#         SINALOA  2023     81514  90021 IMSS Bienestar
#          SONORA  2023         0      0 IMSS Bienestar
#      TAMAULIPAS  2023    181559 196895 IMSS Bienestar
#        VERACRUZ  2023    133909 140585 IMSS Bienestar
#         YUCATÁN  2023     74508  77501 IMSS Bienestar
#       ZACATECAS  2023    148857 153557 IMSS Bienestar
# BAJA CALIFORNIA  2024     12176  12746 IMSS Bienestar
#        CAMPECHE  2024     11280  12708 IMSS Bienestar
#         CHIAPAS  2024     74253  80441 IMSS Bienestar
#       CHIHUAHUA  2024     40402  46088 IMSS Bienestar
#        COAHUILA  2024     31975  32728 IMSS Bienestar
#         DURANGO  2024     76053  76370 IMSS Bienestar
#        GUERRERO  2024      7994   8423 IMSS Bienestar
#         HIDALGO  2024     58418  59635 IMSS Bienestar
#          MÉXICO  2024     21944  22436 IMSS Bienestar
#       MICHOACÁN  2024     86183  95920 IMSS Bienestar
#         NAYARIT  2024     10534  10638 IMSS Bienestar
#          OAXACA  2024    103427 104055 IMSS Bienestar
#          PUEBLA  2024     70278  75454 IMSS Bienestar
# SAN LUIS POTOSI  2024     61896  69693 IMSS Bienestar
#         SINALOA  2024     42383  44147 IMSS Bienestar
#          SONORA  2024      3742   5278 IMSS Bienestar
#      TAMAULIPAS  2024     42243  47386 IMSS Bienestar
#        VERACRUZ  2024     47481  48386 IMSS Bienestar
#         YUCATÁN  2024     27793  28757 IMSS Bienestar
#       ZACATECAS  2024     56392  58789 IMSS Bienestar

# %% [markdown]
# ## 2. Dataset unificado

# %%
df = load_all(DATA_DIR)
df['theta_obs'] = df['surtidas'] / df['total']

print(f"Total de observaciones: {len(df)}")
print()
display(
    df.groupby('institucion').agg(
        estados=('estado', 'nunique'),
        anios=('anio', 'nunique'),
        filas=('estado', 'count'),
        recetas_total=('total', 'sum'),
        recetas_surtidas=('surtidas', 'sum'),
    ).assign(
        theta_global=lambda x: x['recetas_surtidas'] / x['recetas_total']
    ).round({'theta_global': 4})
)
# Out:
# Total de observaciones: 576
#                 estados  anios  filas  recetas_total  recetas_surtidas  \
# institucion
# IMSS                 32      6    192     1212867806        1150318301
# IMSS Bienestar       20      8    160       20525728          19167060
# ISSSTE               32      7    224      238863549         233332377
#
#                 theta_global
# institucion
# IMSS                  0.9484
# IMSS Bienestar        0.9338
# ISSSTE                0.9768

# %% [markdown]
# ## 3. Cobertura temporal por institución

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 5))
instituciones = ['ISSSTE', 'IMSS', 'IMSS Bienestar']
colores = ['#2563eb', '#16a34a', '#dc2626']

for ax, inst, color in zip(axes, instituciones, colores):
    sub = df[df.institucion == inst].copy()
    pivot = sub.pivot_table(index='estado', columns='anio', values='theta_obs', aggfunc='mean')
    im = ax.imshow(pivot.values, aspect='auto', vmin=0.7, vmax=1.0, cmap='RdYlGn')
    ax.set_title(inst, fontsize=11, fontweight='bold', color=color)
    ax.set_xticks(range(len(pivot.columns)))
    ax.set_xticklabels(pivot.columns.astype(int), rotation=45, ha='right', fontsize=8)
    ax.set_yticks(range(len(pivot.index)))
    ax.set_yticklabels(pivot.index, fontsize=7)
    plt.colorbar(im, ax=ax, label='θ observada')

fig.suptitle('Tasa de surtimiento completo (θ) por estado y año', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Distribución de θ por institución

# %%
fig, ax = plt.subplots(figsize=(9, 4))

for inst, color in zip(instituciones, colores):
    sub = df[df.institucion == inst]['theta_obs'].dropna()
    ax.hist(sub, bins=30, alpha=0.5, color=color, label=inst, density=True)
    ax.axvline(sub.mean(), color=color, lw=2, linestyle='--',
               label=f'{inst} μ={sub.mean():.3f}')

ax.set_xlabel('θ observada (recetas completamente surtidas / total)')
ax.set_ylabel('Densidad')
ax.set_title('Distribución de la tasa de surtimiento completo')
ax.legend()
plt.tight_layout()
plt.show()

print(df.groupby('institucion')['theta_obs'].describe().round(4))
# Out:
#                 count    mean     std     min     25%     50%     75%     max
# institucion
# IMSS            192.0  0.9455  0.0414  0.7999  0.9220  0.9600  0.9785  0.9994
# IMSS Bienestar  153.0  0.9310  0.0489  0.7090  0.9006  0.9399  0.9693  0.9996
# ISSSTE          224.0  0.9730  0.0180  0.8602  0.9684  0.9763  0.9840  0.9958

# %% [markdown]
# ## 5. Tendencia temporal agregada

# %%
fig, ax = plt.subplots(figsize=(9, 4))

for inst, color in zip(instituciones, colores):
    sub = (
        df[df.institucion == inst]
        .groupby('anio')[['surtidas', 'total']].sum()
        .assign(theta=lambda x: x.surtidas / x.total)
    )
    ax.plot(sub.index, sub['theta'], marker='o', color=color, label=inst, lw=2)

ax.set_xlabel('Año')
ax.set_ylabel('θ agregada nacional')
ax.set_title('Tendencia de surtimiento completo nacional por institución')
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1, decimals=1))
ax.set_xticks(range(2017, 2025))
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Preparar inputs para PyMC
#
# Se construyen los arrays de índices y observaciones usando `build_model_inputs()` del módulo `bayes_data`. Se puede llamar por institución o sobre el dataset completo.

# %%
# Filtrar años de análisis: 2019-2023 (período comparable entre las tres instituciones)
# Se excluye 2024 (datos parciales hasta abril) y años anteriores a 2019 (IMSS no tiene)
ANIO_MIN, ANIO_MAX = 2019, 2023

df_modelo = df[df.anio.between(ANIO_MIN, ANIO_MAX) & (df.total > 0)].copy()
df_modelo = df_modelo.drop(columns='theta_obs').reset_index(drop=True)

# Guardar base de análisis
out_path = DATA_DIR / 'base_modelo_2019_2023.csv'
df_modelo.to_csv(out_path, index=False)
print(f"CSV guardado → {out_path}")
print(f"Filas: {len(df_modelo)}  |  columnas: {df_modelo.columns.tolist()}")
print()
print(df_modelo.groupby('institucion').agg(
    estados=('estado', 'nunique'),
    anios=('anio', 'nunique'),
    filas=('estado', 'count'),
))

# Inputs por institución sobre la base filtrada
inputs = {}
for inst in instituciones:
    sub = df_modelo[df_modelo.institucion == inst].copy()
    inputs[inst] = build_model_inputs(sub)
    d = inputs[inst]
    print(f"\n{inst}: {len(d['n_obs'])} obs | "
          f"{len(d['coords']['estados'])} estados | "
          f"años: {d['coords']['anios']} | "
          f"θ_obs médiana={np.median(d['theta_obs']):.4f}")
# Out:
# CSV guardado → /Users/main/Documents/ciencia_de_datos/Programacion probabilistica/final-project-pp-dj/data/base_modelo_2019_2023.csv
# Filas: 415  |  columnas: ['estado', 'anio', 'surtidas', 'total', 'institucion']
#
#                 estados  anios  filas
# institucion
# IMSS                 32      5    160
# IMSS Bienestar       19      5     95
# ISSSTE               32      5    160
#
# ISSSTE: 160 obs | 32 estados | años: [np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023)] | θ_obs médiana=0.9737
#
# IMSS: 160 obs | 32 estados | años: [np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023)] | θ_obs médiana=0.9459
#
# IMSS Bienestar: 95 obs | 19 estados | años: [np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023)] | θ_obs médiana=0.9255
